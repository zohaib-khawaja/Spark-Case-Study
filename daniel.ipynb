# %%
import pyspark as ps
import json
import pandas as pd

spark = ps.sql.SparkSession.builder.master("local[4]").appName('df case study').getOrCreate()

sc = ps.SparkContext

tweets_df = spark.read.json('./data/french_tweets.json').sample(False, 0.02)
# Out:
# root
#  |-- contributors: string (nullable = true)
#  |-- coordinates: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- display_text_range: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- entities: struct (nullable = true)
#  |    |-- hashtags: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
# ...

# %%
tweets_df.select('user.created_at').show(2)
# Out:
# +--------------------+
# |          created_at|
# +--------------------+
# |Sun Apr 05 16:03:...|
# |Sat Feb 19 19:05:...|
# +--------------------+
# only showing top 2 rows

# %%
tweets_df.printSchema()
# Out:
# root
#  |-- contributors: string (nullable = true)
#  |-- coordinates: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- display_text_range: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- entities: struct (nullable = true)
#  |    |-- hashtags: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
# ...

# %%
pandas_df = tweets_df.toPandas()

# %%
pandas_df.iloc[0].to_json()
print(json.dumps(json.loads(pandas_df.iloc[0].to_json()), indent=4, sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Wed Apr 26 13:30:46 +0000 2017",
#     "display_text_range": [
#         25,
#         82
#     ],
#     "entities": [
#         [],
#         null,
#         [],
#         [],
#         [
#             [
#                 326757541,
#                 "326757541",
#                 [
#                     0,
#                     9
#                 ],
#                 "L'Echo R\u00e9publicain",
#                 "lecho_fr"
#             ],
#             [
#                 3482554756,
#                 "3482554756",
#                 [
#                     10,
#                     24
#                 ],
#                 "La Saucelle Off",
#                 "lasaucelleoff"
#             ]
#         ]
#     ],
#     "extended_entities": null,
#     "extended_tweet": null,
#     "favorite_count": 0.0,
#     "favorited": false,
#     "filter_level": "low",
#     "geo": null,
#     "id": 8.572254412e+17,
# ...

# %%
pandas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43229 entries, 0 to 43228
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   contributors               0 non-null      object
#  1   coordinates                3613 non-null   object
#  2   created_at                 43227 non-null  object
#  3   display_text_range         21426 non-null  object
#  4   entities                   43227 non-null  object
#  5   extended_entities          4557 non-null   object
#  6   extended_tweet             4387 non-null   object
#  7   favorite_count             43227 non-null  float64
#  8   favorited                  43227 non-null  object
#  9   filter_level               43227 non-null  object
#  10  geo                        3613 non-null   object
#  11  id                         43227 non-null  float64
#  12  id_str                     43227 non-null  object
# ...

# %%
pandas_df[['created_at', 'entities', 'favorite_count', 'favorited', 'filter_level', 'id', 'id_str', 'in_reply_to_user_id', 'lang', 'place', 'possibly_sensitive', 'retweet_count', 'retweeted', 'source', 'text', 'timestamp_ms', 'user']].iloc[:40]['user']
# Out:
# 0     (False, Mon Dec 05 16:07:15 +0000 2016, False,...
# 1     (False, Mon Mar 28 17:18:23 +0000 2011, True, ...
# 2     (False, Thu Nov 01 00:38:57 +0000 2012, True, ...
# 3     (False, Sat Dec 27 17:46:48 +0000 2014, False,...
# 4     (False, Fri Jun 11 17:55:52 +0000 2010, False,...
# 5     (False, Wed Mar 08 09:13:45 +0000 2017, True, ...
# 6     (False, Thu Jul 24 09:23:24 +0000 2014, True, ...
# 7     (False, Thu Sep 18 08:10:41 +0000 2014, False,...
# 8     (False, Sun Jul 22 21:12:50 +0000 2012, False,...
# 9     (False, Mon Feb 10 12:59:58 +0000 2014, False,...
# 10    (False, Tue Jul 14 11:52:38 +0000 2015, False,...
# 11    (False, Fri Oct 30 13:35:21 +0000 2009, True, ...
# 12    (False, Mon Jan 06 20:04:01 +0000 2014, False,...
# 13    (False, Mon Sep 21 17:57:36 +0000 2015, True, ...
# 14    (False, Wed Dec 09 14:12:26 +0000 2015, False,...
# 15    (False, Tue Oct 06 18:13:27 +0000 2009, False,...
# 16    (False, Sun Dec 16 14:26:02 +0000 2012, False,...
# ...

# %%
print(pandas_df[pandas_df['display_text_range'].notna()][['display_text_range', 'is_quote_status', 'text']].iloc[:40])
# Out:
#    display_text_range is_quote_status  \
# 0            [25, 82]           False
# 3            [14, 59]           False
# 11            [0, 68]            True
# 15          [43, 101]           False
# 16            [0, 29]            True
# 20           [13, 57]           False
# 21            [0, 26]           False
# 22           [27, 97]           False
# 23           [0, 115]           False
# 24          [53, 125]           False
# 30           [10, 10]           False
# 31           [23, 37]           False
# 32           [30, 46]           False
# 33            [9, 14]           False
# 36           [16, 88]           False
# 37           [16, 98]           False
# 38           [14, 34]           False
# 39           [0, 140]            True
# 40           [22, 51]           False
# 42           [0, 140]           False
# 43            [0, 25]           False
# 44            [0, 17]            True
# 45            [0, 18]            True
# ...
